# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime

# %%
df = pd.read_csv(r"C:\Users\ASUS\Downloads\Amazon Sales data.csv")

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
df.tail()
# Out:
#                 Region       Country      Item Type Sales Channel  \
# 95  Sub-Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub-Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub-Saharan Africa    Mozambique      Household       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 95              M   7/26/2011  512878119    9/3/2011         888      109.28
# 96              L  11/11/2011  810711038  12/28/2011        6267        9.33
# 97              C    6/1/2016  728815257   6/29/2016        1485      154.06
# 98              M   7/30/2015  559427106    8/8/2015        5767       81.73
# 99              L   2/10/2012  665095412   2/15/2012        5367      668.27
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.shape
# Out:
# (100, 14)

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df.dropna(inplace = True)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    datetime64[ns]
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    datetime64[ns]
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 11.1+ KB

# %%
df.size
# Out:
# 1400

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (100, 14)

# %%
df['Region'].unique()
# Out:
# array(['Australia and Oceania', 'Central America and the Caribbean',
#        'Europe', 'Sub-Saharan Africa', 'Asia',
#        'Middle East and North Africa', 'North America'], dtype=object)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Month'] = df['Order Date'].dt.month

# %%
print(df)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df['Year'] = df['Order Date'].dt.year

# %%
print(df)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# # Visualization

# %%
ax = df.groupby(['Month'],as_index = False)['Units Sold'].sum()
sns.lineplot(x = "Month", y = "Units Sold", data = df)
# Out:
# <Axes: xlabel='Month', ylabel='Units Sold'>

# %%
# The hishest units sold is in the month of 7th(i.e July).
# tHERE IS SHARP DECLINE AT THE END OF THE YEAR.

# %%
ax = df.groupby(['Year'],as_index = False)['Units Sold'].sum()

# %%
plt.title('Yearly Sales Trend')
plt.xlabel('Year')
plt.ylabel('Total Sales')
bx = sns.lineplot(x = 'Year', y ='Units Sold' , data = df)

# %%
# We can obsereve there was major decline in the sales in 2011..
#the highest sales are in the year 2010,2014 and 2017.

# %%
dx = df.groupby(['Year','Month'],as_index = False)['Units Sold'].sum()

# %%
ex = sns.lineplot(x = 'Month', y = 'Units Sold', hue = 'Year', data = df)

# %%
# tHE HIGHEST SALES IS IN THE YEAR 2012 OF MONTH 7(I.E jULY)

# %%
gx = df.groupby(['Item Type'],as_index = False)['Units Sold'].sum()

# %%
plt.figure(figsize =(20,5))
hx = sns.barplot(x = 'Item Type', y= 'Units Sold', data = df)

# %%
# THE HIGHEST SALES OF A PRTICULAR PRODUCT THROUGHOUT THE SEVERAL YEARS IS beverages.

# %%
ix = df.groupby(['Region'], as_index = False)['Total Profit'].sum()

# %%
plt.figure(figsize =(20,5))
region_wise_profit=sns.barplot(x = 'Region', y= 'Total Profit', data = df)

# %%
# The highest PROFIT EARNED BY North AMERICA.

# %%
plt.figure(figsize =(20,5))
kx = sns.barplot(x = 'Item Type', y = 'Total Profit', hue = 'Region', data = df)

# %%
# THE HIGHEST PROFIT EARNED BY COSMETIC INDUSTRY OF MIDDLE EAST AND NORTH AFRICA.
# THE LOWEST PROFIT EARNED BY FRUITS FOR ALL THE COUNTRIES.
# the highest profit of household chores earned by north america.

# %%
plt.figure(figsize=(20,5))
lx =sns.lineplot(x='Item Type', y='Total Revenue', data=df, label='Total Revenue')
mx = sns.lineplot(x= 'Item Type', y = 'Total Profit',data = df, label = 'Total Profit')

# %%
# THE TOTAL REVENUE GIVEN IS IN HOUSEHOLD PRODUCT.
# THE PROFIT EARNED BY COSMETIC INDUSTRY IS MAXIMUM .

# %%
plt.figure(figsize=(20,5))
lx =sns.scatterplot(x='Item Type', y='Total Cost', data=df, label='Total Cost')
mx = sns.scatterplot(x= 'Item Type', y = 'Total Profit',data = df, label = 'Total Profit')
plt.legend()
plt.title('Scatter plot of btw total profit and total cost with respect to Item Type')
plt.grid(True)
plt.show()

# %%
df.groupby(['Sales Channel'], as_index = False)['Total Profit'].sum()
sns.barplot(x = 'Sales Channel', y = 'Total Profit', data = df)
plt.title('Total Profit w.r.t. Sales Channel')
# Out:
# Text(0.5, 1.0, 'Total Profit w.r.t. Sales Channel')

# %%
# THE  MAX. PROFIT EARNED IS THORUGH OFFLINE SALES.

# %%
sns.barplot(x = 'Sales Channel', y = 'Total Profit',hue = 'Region',  data = df)
plt.title('Total Profit depending upon Sales Channels w.r.t Region')
# Out:
# Text(0.5, 1.0, 'Total Profit depending upon Sales Channels w.r.t Region')

# %%
# THE OFFLINE SALES IS MAXIMUM IN MIDDLE EAST AND NORTH AFRICA REGION.

# %%
sns.scatterplot(x ="Order Date", y = "Ship Date", hue = "Order Priority", data = df)
# Out:
# <Axes: xlabel='Order Date', ylabel='Ship Date'>

# %%
sns.countplot(x = "Order Priority", data = df)
# Out:
# <Axes: xlabel='Order Priority', ylabel='count'>

# %%
# h denotes highest priority
# c denotes critical priroity
# l means Low priority
# m denotes medium priority
# the most of the product to be delivered to customer is of highest priority.

# %%
sns.countplot(x = "Region", hue = "Order Priority", data = df)

plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Australia and Oceania'),
#   Text(1, 0, 'Central America and the Caribbean'),
#   Text(2, 0, 'Europe'),
#   Text(3, 0, 'Sub-Saharan Africa'),
#   Text(4, 0, 'Asia'),
#   Text(5, 0, 'Middle East and North Africa'),
#   Text(6, 0, 'North America')])

# %%
# the order is at highest priority from Sub- Saharan africa region.
